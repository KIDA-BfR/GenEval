# %% [markdown]
# ## Data and libraries load
#
# Load xlsx files from the extraction pipeline.

# %%
from validation_package import reading_tables
#/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/use_case_content/truth_table.xlsx
#/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/use_case_content/compared_table.xlsx

table_truth, table_compared = reading_tables("/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/use_case_content/truth_table.xlsx","/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/use_case_content/compared_table.xlsx", display_tables=True)
# Out:
#           Nb       String  string noisy          list nb  ordered list nb  \
# 0     3.00000         DFGE    dfgrhgfds            6,9,7            6,9,7
# 1   575.00000  je suis sat      sdfvgbn              NaN              NaN
# 2    45.90000        à oui      sedrtyu            1,2,3            1,2,3
# 3  1000.00000      OLALAla      ertyunk  5,0,6,45,679.65  5,0,6,45,679.65
# 4     0.84756            g      DEFRGHJ      12,9876,0.2      12,9876,0.2
# 5    34.00000      GgGgGzo          NaN              NaN              NaN
#
#        list string
# 0      hahaha,hehe
# 1      a,b,c,d,e,f
# 2              NaN
# 3  sh,ch,sch,th,ph
# 4              NaN
# 5  OTRH,GJKO,hfhjz
#           Nb       String  string noisy          list nb  ordered list nb  \
# 0     3.00000     DeFeEeGe    dfgrhgfuy            9,6,7            6,9,7
# 1   575.00000  je suis sat            x              NaN              NaN
# 2    45.90000        à oui      sedrtyu          3,1,2,3            1,2,3
# ...

# %% [markdown]
# ## Applying glossaries
#
# Glossaries allow to provide the term equivalency ensuring a proper validation

# %%
from validation_package import sort_data

table_truth, table_compared = sort_data(table_truth, table_compared, glossary=None)

# %% [markdown]
# ## Columns processing

# %% [markdown]
# ### Assigning columns to specific pre-processing routines

# %%
#manual attribution
from validation_package import manual_process_for_columns_attribution

attribution_file1 = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/use_case_content/manual_attribution_ex.txt"
attribution_file2 = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/use_case_content/manual_counter_ex1.txt"
attribution_file3 = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/use_case_content/manual_counter_ex2.txt"
processors = manual_process_for_columns_attribution(table_truth, attribution_file1)
print(processors)
# Out:
# What type of processing for each column ?
# Write a txt file via choosing from this table:
# Processing methods
# -------------------
# num - NumericColumnProcessor()
# words - StringColumnProcessor()
# words_not_exact - StringNoisyColumnProcessor()
# list_num - List_of_Numbers_ColumnProcessor()
# ordered_list_num - Ordered_List_of_Numbers_ColumnProcessor()
# list_words - List_of_Strings_ColumnProcessor()
# ['Nb', 'String', 'string noisy', 'list nb', 'ordered list nb', 'list string']
# ...

# %%
#automatic attribution
from validation_package import automatic_process_for_columns_attribution

processors = automatic_process_for_columns_attribution(table_truth)
print(processors)
# Out:
# The JSON file holding the attribution has been saved on your end.

# %%
#editing automatic attribution
from validation_package import modify_attribution

new_attribution = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/validation_library/new_attribution.json"
new_processors = modify_attribution(new_attribution)
print(new_processors)
# Out:
# Nb : <validation_package.classes.NumericColumnProcessor object at 0x00000183E8CE5E80>
# String : <validation_package.classes.StringColumnProcessor object at 0x00000183E8CE5550>
# string noisy : <validation_package.classes.StringNoisyColumnProcessor object at 0x00000183E8D3B750>
# list nb : <class 'validation_package.classes.List_of_Numbers_ColumnProcessor'>
# ordered list nb : <class 'validation_package.classes.Ordered_List_of_Numbers_ColumnProcessor'>
# list string : <class 'validation_package.classes.List_of_Strings_ColumnProcessor'>
# The attribution has been edited.

# %% [markdown]
# ## Comparison process

# %% [markdown]
# ### Comparison and storage

# %%
from validation_package import comparison_init

comparison_results, confusion_matrices = comparison_init(table_truth, table_compared, processors)

# %% [markdown]
# ### Formatting the result

# %%
from validation_package.get_results import results

combined_output, confusion_matrices_df = results(table_truth, table_compared, comparison_results, confusion_matrices, display_results=True)
# Out:
#      Nb_truth  Nb_compared Nb_comparison String_truth String_compared  \
# 0     0.84756      0.84756       Correct            g               g
# 1     3.00000      3.00000       Correct         DFGE        DeFeEeGe
# 2    34.00000     34.00000       Correct      GgGgGzo         GgGgGzo
# 3    45.90000     45.90000       Correct        à oui           à oui
# 4   575.00000    575.00000       Correct  je suis sat     je suis sat
# 5  1000.00000   1000.00000       Correct      OLALAla         OLALAla
#
#   String_comparison string noisy_truth string noisy_compared  \
# 0           Correct            DEFRGHJ               DEFRGHm
# 1         Incorrect          dfgrhgfds             dfgrhgfuy
# 2           Correct                NaN                   NaN
# 3           Correct            sedrtyu               sedrtyu
# 4           Correct            sdfvgbn                     x
# 5           Correct            ertyunk               ertyuaz
#
# ...
