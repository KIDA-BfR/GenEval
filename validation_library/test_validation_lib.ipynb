# %% [markdown]
# ## Data and libraries load
#
# Load xlsx files from the extraction pipeline.

# %%
from validation_package.load import dataframe_impl, reading_tables
#/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/content/truth_table.xlsx
#/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/content/compared_table.xlsx

table_truth, table_compared = reading_tables("/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/content/truth_table.xlsx","/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/content/compared_table.xlsx")

print(f"Truth table: \n{table_truth}")
#print(f"\nCompared table: \n{table_compared}")
# Out:
# Truth table:
#           Nb       String  string noisy          list nb  ordered list nb  \
# 0     3.00000         DFGE    dfgrhgfds            6,9,7            6,9,7
# 1   575.00000  je suis sat      sdfvgbn              NaN              NaN
# 2    45.90000        à oui      sedrtyu            1,2,3            1,2,3
# 3  1000.00000      OLALAla      ertyunk  5,0,6,45,679.65  5,0,6,45,679.65
# 4     0.84756            g      DEFRGHJ      12,9876,0.2      12,9876,0.2
# 5    34.00000      GgGgGzo          NaN              NaN              NaN
#
#        list string
# 0      hahaha,hehe
# 1      a,b,c,d,e,f
# 2              NaN
# 3  sh,ch,sch,th,ph
# 4              NaN
# 5  OTRH,GJKO,hfhjz

# %% [markdown]
# ## Applying glossaries
#
# Glossaries allow to provide the term equivalency ensuring a proper validation

# %%
from validation_package.sort_and_glossary import sort_data

sort_data(table_truth, table_compared)

# %% [markdown]
# ## Columns processing

# %% [markdown]
# ### Assigning columns to specific pre-processing routines

# %%
#manual attribution
from validation_package.columns_attribution import manual_process_for_columns_attribution

attribution_file1 = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/content/manual_attribution_ex.txt"
attribution_file2 = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/content/manual_counter_ex1.txt"
attribution_file3 = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/content/manual_counter_ex2.txt"
processors = manual_process_for_columns_attribution(table_truth, attribution_file1)
print(processors)
# Out:
# What type of processing for each column ?
# Write a txt file via choosing from this table:
# Processing methods
# -------------------
# num - NumericColumnProcessor()
# words - StringColumnProcessor()
# words_not_exact - StringNoisyColumnProcessor()
# list_num - List_of_Numbers_ColumnProcessor()
# ordered_list_num - Ordered_List_of_Numbers_ColumnProcessor()
# list_words - List_of_Strings_ColumnProcessor()
# ['Nb', 'String', 'string noisy', 'list nb', 'ordered list nb', 'list string']
# ['NumericColumnProcessor', 'StringColumnProcessor', 'StringNoisyColumnProcessor', 'List_of_Numbers_ColumnProcessor', 'Ordered_List_of_Numbers_ColumnProcessor', 'List_of_Strings_ColumnProcessor']
# The manual attribution was taken into account.

# %%
#automatic attribution
from validation_package.columns_attribution import automatic_process_for_columns_attribution, modify_attribution

processors = automatic_process_for_columns_attribution(table_truth)
print(processors)

# attribution = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/attribution.json"
# new_processors = modify_attribution(attribution)
# print(new_processors)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       1 #automatic attribution
#       2 from libraries.valid_columns_4 import automatic_process_for_columns_attribution, modify_attribution
# ----> 4 processors = automatic_process_for_columns_attribution(table_truth)
#       5 print(processors)
#       7 # attribution = "/Users/meltr/OneDrive/Documents/(APT2)/D4/STAGE/github/GenEval/libraries/attribution.json"
#       8 # new_processors = modify_attribution(attribution)
#       9 # print(new_processors)
#
# File c:\Users\meltr\OneDrive\Documents\(APT2)\D4\STAGE\github\GenEval\libraries\libraries\valid_columns_4.py:97, in automatic_process_for_columns_attribution(table_truth)
#      95     if part_types.pop() in (int, float):
#      96         types_in_column.add(list[int])
# ---> 97     elif part_types.pop() is str:
# ...

# %% [markdown]
# ## Comparison process

# %% [markdown]
# ### Comparison and storage

# %%
import pandas as pd
from IPython.display import display
from validation_package.comparison import comparison_init

comparison_results, confusion_matrices = comparison_init(table_truth, table_compared, processors)

# %% [markdown]
# ### Formatting the result

# %%
import pandas as pd 
from IPython.display import display
from validation_package.get_results import results

combined_output, confusion_matrices_df = results(table_truth, table_compared, comparison_results, confusion_matrices)

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', None, 'display.max_colwidth', None):
    display(combined_output)
    display(confusion_matrices_df)
# Out:
#      Nb_truth  Nb_compared Nb_comparison String_truth String_compared  \
# 0     3.00000      3.00000       Correct         DFGE            DFGE
# 1   575.00000    575.00000       Correct  je suis sat     je suis sat
# 2    45.90000     45.90000       Correct        à oui           à oui
# 3  1000.00000   1000.00000       Correct      OLALAla         OLALAla
# 4     0.84756      0.84756       Correct            g               g
# 5    34.00000     34.00000       Correct      GgGgGzo         GgGgGzo
#
#   String_comparison string noisy_truth string noisy_compared  \
# 0           Correct          dfgrhgfds             dfgrhgfuy
# 1           Correct            sdfvgbn                     x
# 2           Correct            sedrtyu               sedrtyu
# 3           Correct            ertyunk               ertyuaz
# 4           Correct            DEFRGHJ               DEFRGHm
# 5           Correct                NaN                   NaN
#
# ...
